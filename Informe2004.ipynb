# %% [markdown]
# # Informe de aportes hidrológicos para el año 2004
# Este es un ejemplo de **clase** sobre *manipulación* de **_archivos_** csv usando python
#
#
# * item 1
# * item 2
# * item 3

# %%
import pandas as pd

# %%
x= pd.read_csv('AportesDiario_2004.csv', sep=';', decimal=',', thousands='.', skiprows=3)
x.head()
# Out:
#         Fecha Region Hidrologica                 Nombre Rio  \
# 0  2004-01-01          ANTIOQUIA             A. SAN LORENZO
# 1  2004-01-01          ANTIOQUIA                 CONCEPCION
# 2  2004-01-01          ANTIOQUIA  DESV. EEPPM (NEC,PAJ,DOL)
# 3  2004-01-01          ANTIOQUIA                     GRANDE
# 4  2004-01-01          ANTIOQUIA                  GUADALUPE
#
#    Aportes Caudal m3/s  Aportes Energia kWh Aportes %
# 0                17.56            3910000.0    72,27%
# 1                 6.15            1385300.0   123,69%
# 2                11.43            2574700.0   147,13%
# 3                18.65            4563500.0    79,23%
# 4                11.28            2540900.0    80,15%

# %%
x['Fecha']
# Out:
# 0       2004-01-01
# 1       2004-01-01
# 2       2004-01-01
# 3       2004-01-01
# 4       2004-01-01
# 5       2004-01-01
# 6       2004-01-01
# 7       2004-01-01
# 8       2004-01-01
# 9       2004-01-01
# 10      2004-01-01
# 11      2004-01-01
# 12      2004-01-01
# 13      2004-01-01
# 14      2004-01-01
# 15      2004-01-01
# 16      2004-01-01
# 17      2004-01-01
# 18      2004-01-01
# 19      2004-01-01
# 20      2004-01-01
# 21      2004-01-01
# 22      2004-01-01
# 23      2004-01-01
# 24      2004-01-02
# 25      2004-01-02
# 26      2004-01-02
# 27      2004-01-02
# 28      2004-01-02
# 29      2004-01-02
#            ...
# 8756    2004-12-30
# 8757    2004-12-30
# 8758    2004-12-30
# 8759    2004-12-30
# 8760    2004-12-31
# 8761    2004-12-31
# 8762    2004-12-31
# 8763    2004-12-31
# 8764    2004-12-31
# 8765    2004-12-31
# 8766    2004-12-31
# 8767    2004-12-31
# 8768    2004-12-31
# 8769    2004-12-31
# 8770    2004-12-31
# 8771    2004-12-31
# 8772    2004-12-31
# 8773    2004-12-31
# 8774    2004-12-31
# 8775    2004-12-31
# 8776    2004-12-31
# 8777    2004-12-31
# 8778    2004-12-31
# 8779    2004-12-31
# 8780    2004-12-31
# 8781    2004-12-31
# 8782    2004-12-31
# 8783    2004-12-31
# 8784           NaN
# 8785           NaN
# Name: Fecha, dtype: object

# %%
x['Region Hidrologica']=='ANTIOQUIA'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 8756    False
# 8757    False
# 8758    False
# 8759    False
# 8760     True
# 8761     True
# 8762     True
# 8763     True
# 8764     True
# 8765     True
# 8766     True
# 8767     True
# 8768     True
# 8769     True
# 8770     True
# 8771    False
# 8772    False
# 8773    False
# 8774    False
# 8775    False
# 8776    False
# 8777    False
# 8778    False
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# 8784    False
# 8785    False
# Name: Region Hidrologica, dtype: bool

# %%
len(x[x['Region Hidrologica']=='ANTIOQUIA'])
# Out:
# 4026

# %%
x[x['Region Hidrologica']=='ANTIOQUIA']
# Out:
#            Fecha Region Hidrologica                 Nombre Rio  \
# 0     2004-01-01          ANTIOQUIA             A. SAN LORENZO
# 8766  2004-12-31          ANTIOQUIA                     MIEL I
# 8767  2004-12-31          ANTIOQUIA                       NARE
# 8768  2004-12-31          ANTIOQUIA                   PORCE II
# 8769  2004-12-31          ANTIOQUIA                 SAN CARLOS
# 8770  2004-12-31          ANTIOQUIA                     TENCHE
#
#      Aportes Caudal m3/s Aportes Energia kWh Aportes %
# 0                  17,56        3.910.000,00    72,27%
# 1                   6,15        1.385.300,00   123,69%
# 2                  11,43        2.574.700,00   147,13%
# 3                  18,65        4.563.500,00    79,23%
# 4                  11,28        2.540.900,00    80,15%
# 5                  32,71        5.405.100,00   141,49%
# 6                  50,63        2.214.100,00    63,99%
# 7                  20,16        7.057.000,00    56,73%
# 8                  64,61        3.242.100,00   120,97%
# 9                  12,80        1.588.700,00    70,92%
# 10                  1,81          407.700,00    66,84%
# 24                 17,18        3.825.300,00    70,71%
# 25                  6,13        1.380.800,00   123,29%
# 26                 11,39        2.565.700,00   146,61%
# 27                 17,73        4.338.400,00    75,32%
# 28                 20,30        4.572.800,00   144,25%
# 29                 18,00        2.974.400,00    77,86%
# 30                 70,57        3.086.100,00    89,19%
# 31                 17,93        6.276.300,00    50,45%
# 32                 64,20        3.221.500,00   120,21%
# 33                 11,84        1.469.500,00    65,60%
# 34                  3,52          792.900,00   129,98%
# 48                 17,00        3.785.300,00    69,97%
# 49                  6,17        1.389.800,00   124,09%
# 50                 11,46        2.581.500,00   147,51%
# 51                 17,48        4.277.200,00    74,26%
# 52                  6,10        1.374.100,00    43,35%
# 53                 12,87        2.126.700,00    55,67%
# 54                 46,76        2.044.800,00    59,10%
# 55                 20,89        7.312.500,00    58,78%
# ...                  ...                 ...       ...
# 8715               26,05        6.353.300,00    79,42%
# 8716               10,66        2.400.400,00    56,61%
# 8717               26,80        4.332.900,00    85,80%
# 8718               82,77        3.623.700,00    78,44%
# 8719               32,64       11.311.200,00    66,03%
# 8720               85,86        4.245.700,00   120,62%
# 8721               14,65        1.764.800,00    52,68%
# 8722                0,71          159.900,00    18,81%
# 8736               19,09        4.171.600,00    60,99%
# 8737                5,22        1.175.400,00    78,36%
# 8738                9,69        2.181.900,00    95,28%
# 8739               22,12        5.394.800,00    67,44%
# 8740               10,72        2.413.900,00    56,93%
# 8741               26,67        4.311.900,00    85,38%
# 8742               71,47        3.129.000,00    67,73%
# 8743               24,47        8.480.000,00    49,50%
# 8744               73,77        3.647.900,00   103,63%
# 8745               14,36        1.729.900,00    51,64%
# 8746                0,72          162.100,00    19,07%
# 8760               18,82        4.112.600,00    60,13%
# 8761                5,16        1.161.900,00    77,46%
# 8762                9,57        2.154.900,00    94,10%
# 8763               23,37        5.699.700,00    71,25%
# 8764                9,92        2.233.700,00    52,68%
# 8765               18,18        2.939.300,00    58,20%
# 8766               76,67        3.356.700,00    72,66%
# 8767               29,37       10.178.000,00    59,42%
# 8768               74,85        3.701.300,00   105,15%
# 8769               14,26        1.717.800,00    51,28%
# 8770                2,34          526.900,00    61,99%
#
# [4026 rows x 6 columns]

# %%
seleccion = x['Region Hidrologica'] =='ANTIOQUIA'

# %%
len(x[seleccion])
# Out:
# 4026

# %%
set(x['Nombre Rio'])
# Out:
# {nan,
#  'PRADO',
#  'A. SAN LORENZO',
#  'CALIMA',
#  'GUADALUPE',
#  'NARE',
#  'BATA',
#  'BOGOTA N.R.',
#  'PORCE II',
#  'ALTOANCHICAYA',
#  'TENCHE',
#  'MAGDALENA BETANIA',
#  'SINU URRA',
#  'FLORIDA II',
#  'SAN CARLOS',
#  'GUATAPE',
#  'GUAVIO',
#  'CONCEPCION',
#  'DESV. EEPPM (NEC,PAJ,DOL)',
#  'CHUZA',
#  'OTROS RIOS (ESTIMADOS)',
#  'MIEL I',
#  'CAUCA SALVAJINA',
#  'DIGUA',
#  'GRANDE'}

# %%
x.groupby('Nombre Rio').mean()
# Out:
#                            Aportes Caudal m3/s  Aportes Energia kWh
# Nombre Rio
# A. SAN LORENZO                       36.466612         8.105400e+06
# ALTOANCHICAYA                        43.468716         4.620596e+06
# BATA                                 95.478989         1.571243e+07
# BOGOTA N.R.                          28.051803         1.277674e+07
# CALIMA                               11.922077         5.560117e+05
# CAUCA SALVAJINA                     113.523306         2.519614e+06
# CHUZA                                 9.742486         4.337967e+06
# CONCEPCION                            6.606667         1.488170e+06
# DESV. EEPPM (NEC,PAJ,DOL)             8.312240         2.291866e+06
# DIGUA                                27.529536         4.299954e+05
# FLORIDA II                           10.712486         2.148367e+05
# GRANDE                               27.511967         6.729973e+06
# GUADALUPE                            20.167978         4.542911e+06
# GUATAPE                              34.103033         5.624479e+06
# GUAVIO                               85.884563         2.062469e+07
# MAGDALENA BETANIA                   374.490765         5.580630e+06
# MIEL I                               78.433251         3.430428e+06
# NARE                                 49.711612         1.738808e+07
# OTROS RIOS (ESTIMADOS)                     NaN         3.700457e+06
# PORCE II                             99.292650         4.976887e+06
# PRADO                                45.597268         4.984191e+05
# SAN CARLOS                           24.910492         3.084509e+06
# SINU URRA                           284.444208         3.165074e+06
# TENCHE                                3.900874         8.786683e+05

# %%
n=set(x['Nombre Rio'])
n
# Out:
# {nan,
#  'PRADO',
#  'A. SAN LORENZO',
#  'CALIMA',
#  'GUADALUPE',
#  'NARE',
#  'BATA',
#  'BOGOTA N.R.',
#  'PORCE II',
#  'ALTOANCHICAYA',
#  'TENCHE',
#  'MAGDALENA BETANIA',
#  'SINU URRA',
#  'FLORIDA II',
#  'SAN CARLOS',
#  'GUATAPE',
#  'GUAVIO',
#  'CONCEPCION',
#  'DESV. EEPPM (NEC,PAJ,DOL)',
#  'CHUZA',
#  'OTROS RIOS (ESTIMADOS)',
#  'MIEL I',
#  'CAUCA SALVAJINA',
#  'DIGUA',
#  'GRANDE'}

# %%
import statistics

# %%
for y in n:
    z= x[x['Nombre Rio']==y]['Aportes Energia kWh']
    if len(z) > 0:
        print(y, statistics.mean(x[x['Nombre Rio']==y]['Aportes Energia kWh'].values[:]))
# Out:
# PRADO 498419.125683
# A. SAN LORENZO 8105399.72678
# CALIMA 556011.748634
# GUADALUPE 4542910.92896
# NARE 17388083.6066
# BATA 15712428.4153
# BOGOTA N.R. nan
# PORCE II 4976887.15847
# ALTOANCHICAYA 4620595.90164
# TENCHE 878668.306011
# MAGDALENA BETANIA 5580630.32787
# SINU URRA 3165074.04372
# FLORIDA II nan
# SAN CARLOS 3084508.74317
# GUATAPE 5624479.23497
# GUAVIO 20624689.3443
# CONCEPCION 1488170.4918
# DESV. EEPPM (NEC,PAJ,DOL) nan
# CHUZA nan
# OTROS RIOS (ESTIMADOS) 3700456.8306
# MIEL I 3430428.4153
# CAUCA SALVAJINA 2519614.48087
# DIGUA 429995.355191
# GRANDE 6729973.22404
